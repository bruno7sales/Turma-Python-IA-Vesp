# %% [markdown]
# # Titulo!!!
#
# ## Subtitulo!!
#
# *Italico*<br />
# **Negrito**<br />
# ***Negrito em itálico***<br />
#
# Esse é um texto normal
#
# Exemplo de codigo *Hello world* no *markdown*:<br />
# `print("Hello World)`.
# <br />
# <br />
# 1. Você vai clicar em "Não"?<br /><br />
# <input type="radio" nome="questao"/><span>Sim</span><br />
# <input type="radio" nome="questao"/><span>Não</span><br />
# <br />
# 2. Selecione a melhor linguagem: <br /><br />
# <input type="checkbox" nome="hab"/>Operador de Micro<br />
# <input type="checkbox" nome="hab"/>HTML<br />
# <input type="checkbox" nome="hab"/>Java<br />
# <input type="checkbox" nome="hab"/>Python<br />
#
# ## Tópico:
#
# - Tópico 1
# - Tópico 2
# - Tópico 3
#
# ## Numeração:
#
# 1. Numeração 1
# 2. Numeração 2
# 3. Numeração 3
#
# ## Trbalhando com codigos em Jupyter:
#
# Abaixo segue um exemplo de um código funcional em **Python**rodando em um *notebook*:

# %%
n1 = 15
n2 = 5
n3 = n1+n2

print(f'Qual é o fileme: \nResposta: O Codigo da {n3}')
# Out:
# Qual é o fileme:
# Resposta: O Codigo da 20

# %% [markdown]
# Repare no codigo-fonte das celular consideram o resultado das celulas anteriores do mesmo notebook. OBSERVE NO CODIGO

# %%
X = 10

print(f'Resultado = { X *n3}')
# Out:
# Resultado = 200

# %%
texto = input('Informe um texto a ser exibido na celula: ')
print(texto)
# Out:
# Oi lindaum

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Aqui está um exemplo de imagem em markdown!
