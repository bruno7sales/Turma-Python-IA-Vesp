# %% [markdown]
# ***<h1>Os dados contêm as seguintes informações:</h1>***

# %% [markdown]
# - **País** - este é o país para o qual as informações de vacinação são fornecidas;
#
#
# - **Código ISO do país** - código ISO para o país;
#
#
# - **Data** - data para a entrada de dados; para algumas das datas, temos apenas as vacinações diárias, para outras, apenas o total (cumulativo);
# Número total de vacinações - este é o número absoluto de imunizações totais no país;
#
#
# - **Número total de pessoas vacinadas** - uma pessoa, dependendo do esquema de imunização, receberá uma ou mais (normalmente 2) vacinas; em um determinado momento, o número de vacinações pode ser maior do que o número de pessoas;
#
#
# - **Número total de pessoas totalmente vacinadas** - este é o número de pessoas que receberam todo o conjunto de imunizações de acordo com o esquema de imunização (normalmente 2); em um determinado momento, pode haver um certo número de pessoas que receberam uma vacina e outro número (menor) de pessoas que receberam todas as vacinas no esquema;
#
#
# - **Vacinações diárias (brutas)** - para uma determinada entrada de dados, o número de vacinações para aquela data/país;

# %%
import pandas as pd
import os
import time

# mostra os dados do dataset
tabela = pd.read_csv('country_vaccinations.csv')

ldt = datetime.datetime.now()
print(f"Noteboook last time updated: {ldt.year}-{ldt.month}-{ldt.day}")
# mostra os dados da tabela
display(tabela)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 # mostra os dados do dataset
#       6 tabela = pd.read_csv('country_vaccinations.csv')
# ----> 8 ldt = datetime.datetime.now()
#       9 print(f"Noteboook last time updated: {ldt.year}-{ldt.month}-{ldt.day}")
#      10 # mostra os dados da tabela
#
# NameError: name 'datetime' is not defined

# %% [markdown]
# Inicializamos os pacotes Python que usaremos para ingestão, preparação e visualização de dados. Usaremos principalmente o Plotly para visualização. Então lemos o arquivo de dados e agregamos os dados em alguns campos (país, iso_code e vacinas - que é o esquema de vacinação usado em um determinado país).
#
# Vamos principalmente olhar para:
#
# - Quais esquemas de vacinação são usados ​​em vários países;
# - Número total de vacinações e porcentagem de vacinações;
# - Vacinações diárias e vacinações diárias por milhão;
# - Total de pessoas vacinadas e porcentagem de pessoas vacinadas;
# - No conjunto de dados também há informações sobre o número total de pessoas completamente vacinadas (e porcentagem delas).
#
# Visualizamos os valores mais recentes (máximos) e também a variação no tempo dos valores mencionados acima.

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.graph_objs as go
import plotly.figure_factory as ff
from plotly import tools
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.express as px
init_notebook_mode(connected=True)
import warnings
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data_df = pd.read_csv('country_vaccinations.csv')
display(data_df)
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 25857     Zimbabwe      ZWE  2021-06-16           1120873.0
# 25858     Zimbabwe      ZWE  2021-06-17           1126087.0
# 25859     Zimbabwe      ZWE  2021-06-18           1131397.0
# 25860     Zimbabwe      ZWE  2021-06-19           1133920.0
# 25861     Zimbabwe      ZWE  2021-06-20           1138733.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 25857           697399.0                 423474.0                  7395.0
# 25858           698953.0                 427134.0                  5214.0
# 25859           700244.0                 431153.0                  5310.0
# 25860           701348.0                 432572.0                  2523.0
# 25861           703065.0                 435668.0                  4813.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 25857              5270.0                            7.54
# 25858              5226.0                            7.58
# 25859              4935.0                            7.61
# 25860              4360.0                            7.63
# 25861              4525.0                            7.66
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 25857                           4.69                                 2.85
# 25858                           4.70                                 2.87
# 25859                           4.71                                 2.90
# 25860                           4.72                                 2.91
# 25861                           4.73                                 2.93
#
#        daily_vaccinations_per_million  \
# 0                                 NaN
# 1                                35.0
# 2                                35.0
# 3                                35.0
# 4                                35.0
# ...                               ...
# 25857                           355.0
# 25858                           352.0
# 25859                           332.0
# 25860                           293.0
# 25861                           304.0
#
#                                               vaccines  \
# 0      BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech
# 1      BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech
# 2      BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech
# 3      BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech
# 4      BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech
# ...                                                ...
# 25857                                Sinopharm/Beijing
# 25858                                Sinopharm/Beijing
# 25859                                Sinopharm/Beijing
# 25860                                Sinopharm/Beijing
# 25861                                Sinopharm/Beijing
#
#                      source_name  \
# 0      World Health Organization
# 1      World Health Organization
# 2      World Health Organization
# 3      World Health Organization
# 4      World Health Organization
# ...                          ...
# 25857         Ministry of Health
# 25858         Ministry of Health
# 25859         Ministry of Health
# 25860         Ministry of Health
# 25861         Ministry of Health
#
#                                           source_website
# 0                               https://covid19.who.int/
# 1                               https://covid19.who.int/
# 2                               https://covid19.who.int/
# 3                               https://covid19.who.int/
# 4                               https://covid19.who.int/
# ...                                                  ...
# 25857  https://twitter.com/MoHCCZim/status/1406690528...
# 25858  https://twitter.com/MoHCCZim/status/1406690528...
# 25859  https://twitter.com/MoHCCZim/status/1406690528...
# 25860  https://twitter.com/MoHCCZim/status/1406690528...
# 25861  https://twitter.com/MoHCCZim/status/1406690528...
#
# [25862 rows x 15 columns]

# %%
country_vaccine = data_df.groupby(["country", "iso_code", "vaccines"])[['total_vaccinations', 'total_vaccinations_per_hundred', 'daily_vaccinations', 'daily_vaccinations_per_million', 'people_vaccinated', 'people_vaccinated_per_hundred', 'people_fully_vaccinated', 'people_fully_vaccinated_per_hundred']].max().reset_index()
country_vaccine.columns = [["Country", "iso_code", "Vaccines", "Total vaccinations", "Percent", "Daily vaccinations","Daily vaccinations per million", "People vaccinated", "People vaccinated per hundred", 'People fully vaccinated', 'People fully vaccinated percent']]
display(country_vaccine)
# Out:
#                Country  iso_code  \
# 0          Afghanistan       AFG
# 1              Albania       ALB
# 2              Algeria       DZA
# 3              Andorra       AND
# 4               Angola       AGO
# ..                 ...       ...
# 212              Wales  OWID_WLS
# 213  Wallis and Futuna       WLF
# 214              Yemen       YEM
# 215             Zambia       ZMB
# 216           Zimbabwe       ZWE
#
#                                               Vaccines Total vaccinations  \
# 0      BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech           662003.0
# 1    Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, ...           880912.0
# 2                        Oxford/AstraZeneca, Sputnik V          2500000.0
# 3                  Oxford/AstraZeneca, Pfizer/BioNTech            51107.0
# 4                                   Oxford/AstraZeneca          1380174.0
# ..                                                 ...                ...
# 212       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech          3755314.0
# 213                                 Oxford/AstraZeneca             8657.0
# 214                                 Oxford/AstraZeneca           251385.0
# 215              Oxford/AstraZeneca, Sinopharm/Beijing           148304.0
# 216                                  Sinopharm/Beijing          1138733.0
#
#     Percent Daily vaccinations Daily vaccinations per million  \
# 0      1.70            13921.0                          358.0
# 1     30.61            17565.0                         6104.0
# 2      5.70            22664.0                          517.0
# 3     66.15             1376.0                        17809.0
# 4      4.20            33700.0                         1025.0
# ..      ...                ...                            ...
# 212  119.11            33151.0                        10515.0
# 213   76.98              343.0                        30500.0
# 214    0.84            10240.0                          343.0
# 215    0.81             5680.0                          309.0
# 216    7.66            22863.0                         1538.0
#
#     People vaccinated People vaccinated per hundred People fully vaccinated  \
# 0            484737.0                          1.25                177266.0
# 1            515884.0                         17.93                365028.0
# 2           2500000.0                          5.70                     NaN
# 3             34646.0                         44.84                 16416.0
# 4            866381.0                          2.64                513793.0
# ..                ...                           ...                     ...
# 212         2237710.0                         70.97               1517604.0
# 213            4470.0                         39.75                  4187.0
# 214          251385.0                          0.84                     NaN
# 215          142089.0                          0.77                  6215.0
# 216          703065.0                          4.73                435668.0
#
#     People fully vaccinated percent
# 0                              0.46
# 1                             12.68
# 2                               NaN
# 3                             21.25
# 4                              1.56
# ..                              ...
# 212                           48.13
# 213                           37.23
# 214                             NaN
# 215                            0.03
# 216                            2.93
#
# [217 rows x 11 columns]
